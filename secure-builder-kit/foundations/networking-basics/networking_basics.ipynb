# %% [markdown]
# # Networking Basics Notebook
#
# This notebook demonstrates DNS resolution, TCP handshake concepts, and HTTP request anatomy in a safe observational way.

# %%
from src.networking_basics import dns_lookup, explain_tcp_handshake, http_request_anatomy

# %%
dns_lookup('example.com')

# %%
explain_tcp_handshake('example.com', 80)

# %%
http_request_anatomy('https://example.com')
